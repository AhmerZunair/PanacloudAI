# %%
import pandas as pd
import requests
from matplotlib import pyplot as plt
import numpy as np
url_link=('https://api.cryptonator.com/api/full/btc-usd') 
markets=requests.get(url_link).json()['ticker']['markets']
data=pd.DataFrame(markets)
print(data)
labels=np.array(data['market'].values)                   
prices=np.array((data['price']).values,dtype='float64')  
volumes=np.array(data['volume'].values,dtype='float64')
print("MAX PRICE IS :",np.max(prices))
print("MIN PRICE IS :",np.min(prices))
print("MAX VOLUME IS :",np.max(volumes))
print("MIN VOLUME IS :",np.min(volumes))

plt.figure(num=None, figsize=(8, 6), dpi=100)     
plt.scatter(prices,volumes)                       

for label,price,volume in zip(labels,prices,volumes):  
    plt.annotate(label,
                xy=(price,volume),
                xytext=(5,-5),
                textcoords='offset points',fontsize=10)

plt.xlabel('Price')
plt.ylabel('Volume')
plt.title('Chart For BTC')
plt.show()
# Out:
#       market          price        volume
# 0   BitFinex  9126.30000000  75767.155305
# 1   Bitstamp  9128.00000000  19419.698529
# 2    Bittrex  9150.00000000   4777.313134
# 3      C-Cex  9727.99999999      1.809707
# 4     Cex.io  9372.40000000   2636.085686
# 5       Exmo  9634.00000000   1186.138991
# 6     Hitbtc  9312.77000000   6033.430000
# 7     Kraken  9128.00000000  13979.121975
# 8   Livecoin  9407.61002000   1228.872636
# 9   Poloniex  9136.00010000   4304.602159
# 10     wexnz  9190.00000000   1082.544970
# 11     YoBit  9798.99800000    145.428688
# MAX PRICE IS : 9798.998
# MIN PRICE IS : 9126.3
# MAX VOLUME IS : 75767.155305
# MIN VOLUME IS : 1.80970669

# %%
print('you can buy {} from {} and volume is {}$'.format((labels[11]), prices[11], volumes[11]))
# Out:
# you can buy YoBit from 9798.998 and volume is 145.42868781$
